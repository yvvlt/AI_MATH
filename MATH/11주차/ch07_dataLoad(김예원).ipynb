# %% [markdown]
# 단순선형회귀분석을 위한 데이터 불러오기(data load)
#
# housing.csv 파일을 여기에 업로드하고 프로그램하세요.
#
# 참고싸이트: https://github.com/wikibook/math_dl_book_info/blob/master/notebooks/ch07-regression.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt('housing.csv')
x = data[:, 5] # 6번째 RM
yt = data[:,13]     # 14번째 PRICE
print(x.shape)
print(yt.shape)
# Out:
# (506,)
# (506,)

# %% [markdown]
# 산점도 출력

# %%
# 산점도 출력1
plt.scatter(x, yt)
plt.xlabel('RM')
plt.ylabel('PRICE')
plt.show()

# %%
# 산점도 출력2
plt.figure(figsize=(6, 6))
plt.scatter(x, yt, s=15, c='b', marker='o')
plt.xlabel('RM', fontsize=14)
plt.ylabel('PRICE', fontsize=14)
plt.show()

# %%
# 산점도에 y = -34.1 + 9.1 * x 그래프 추가

# 아래 코드를 작성하시오.
xs = np.array([4, 9])
ys = -34.1 + 9.1 * xs
plt.plot(xs, ys, color='red', label='-34.1 + 9.1x')


plt.legend()
plt.show()
